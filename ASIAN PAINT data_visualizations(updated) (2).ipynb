# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset 
df=pd.read_csv('ASIANPAINT__EQ__NSE__NSE__MINUTE.csv')
df
# Out:
#                         timestamp     open     high      low    close  \
# 0       2017-01-02 09:15:00+05:30   892.55   893.10   891.05   893.00
# 1       2017-01-02 09:16:00+05:30   893.95   894.85   893.20   893.80
# 2       2017-01-02 09:17:00+05:30   893.40   893.95   893.00   893.20
# 3       2017-01-02 09:18:00+05:30   892.25   893.20   891.75   892.50
# 4       2017-01-02 09:19:00+05:30   893.00   893.65   892.70   893.50
# ...                           ...      ...      ...      ...      ...
# 370540  2021-01-01 15:25:00+05:30  2771.90  2772.95  2765.80  2769.70
# 370541  2021-01-01 15:26:00+05:30  2768.70  2771.95  2768.65  2770.95
# 370542  2021-01-01 15:27:00+05:30  2769.95  2770.00  2769.00  2770.00
# 370543  2021-01-01 15:28:00+05:30  2770.00  2770.40  2769.10  2770.00
# 370544  2021-01-01 15:29:00+05:30  2769.10  2772.00  2769.10  2770.10
#
#           volume
# 0         7599.0
# 1         3384.0
# 2         2638.0
# 3       103839.0
# 4         1696.0
# ...          ...
# 370540    5254.0
# 370541    1889.0
# 370542    2439.0
# 370543    2346.0
# 370544    2975.0
#
# [370545 rows x 6 columns]

# %%
#Check the data information using df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370545 entries, 0 to 370544
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  370545 non-null  object
#  1   open       370407 non-null  float64
#  2   high       370407 non-null  float64
#  3   low        370407 non-null  float64
#  4   close      370407 non-null  float64
#  5   volume     370407 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 17.0+ MB

# %%
#Statistical summary
df.describe()
# Out:
#                 open           high            low          close  \
# count  370407.000000  370407.000000  370407.000000  370407.000000
# mean     1450.395211    1451.098381    1449.654451    1450.388201
# std       346.320260     346.544786     346.093261     346.324015
# min       884.950000     885.750000     882.850000     884.950000
# 25%      1161.000000    1161.500000    1160.500000    1161.000000
# 50%      1378.650000    1379.350000    1378.000000    1378.650000
# 75%      1712.600000    1713.650000    1711.600000    1712.600000
# max      2790.950000    2791.700000    2790.000000    2790.950000
#
#               volume
# count  370407.000000
# mean     3752.495838
# std      7661.466604
# min         0.000000
# 25%       830.000000
# 50%      1855.000000
# 75%      4107.000000
# max    955310.000000

# %%
#display first 5 rows
df.head()
# Out:
#                    timestamp    open    high     low  close    volume
# 0  2017-01-02 09:15:00+05:30  892.55  893.10  891.05  893.0    7599.0
# 1  2017-01-02 09:16:00+05:30  893.95  894.85  893.20  893.8    3384.0
# 2  2017-01-02 09:17:00+05:30  893.40  893.95  893.00  893.2    2638.0
# 3  2017-01-02 09:18:00+05:30  892.25  893.20  891.75  892.5  103839.0
# 4  2017-01-02 09:19:00+05:30  893.00  893.65  892.70  893.5    1696.0

# %%
df.dtypes
# Out:
# timestamp     object
# open         float64
# high         float64
# low          float64
# close        float64
# volume       float64
# dtype: object

# %%
#categorical column
cat_col= [col for col in df.columns if df[col].dtype=="object"]
print ("Categorical Columns:", cat_col)
# Out:
# Categorical Columns: ['timestamp']

# %%
#numerical column
num_col=[col for col in df.columns if df[col].dtype!= object]
print("Numerical Column:", num_col)
# Out:
# Numerical Column: ['open', 'high', 'low', 'close', 'volume']

# %%
#Check the total number of Unique Values in the Categorical Columns
df[cat_col].nunique()
# Out:
# timestamp    370545
# dtype: int64

# %%
#to check missing value
df.isna().sum()
# Out:
# timestamp      0
# open         138
# high         138
# low          138
# close        138
# volume       138
# dtype: int64

# %%
df.isna().sum()
# Out:
# timestamp      0
# open         138
# high         138
# low          138
# close        138
# volume       138
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370545 entries, 0 to 370544
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  370545 non-null  object
#  1   open       370407 non-null  float64
#  2   high       370407 non-null  float64
#  3   low        370407 non-null  float64
#  4   close      370407 non-null  float64
#  5   volume     370407 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 17.0+ MB

# %%
# Convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.dtypes
# Out:
# timestamp    datetime64[ns, pytz.FixedOffset(330)]
# open                                       float64
# high                                       float64
# low                                        float64
# close                                      float64
# volume                                     float64
# dtype: object

# %%
df
# Out:
#                        timestamp     open     high      low    close    volume
# 0      2017-01-02 09:15:00+05:30   892.55   893.10   891.05   893.00    7599.0
# 1      2017-01-02 09:16:00+05:30   893.95   894.85   893.20   893.80    3384.0
# 2      2017-01-02 09:17:00+05:30   893.40   893.95   893.00   893.20    2638.0
# 3      2017-01-02 09:18:00+05:30   892.25   893.20   891.75   892.50  103839.0
# 4      2017-01-02 09:19:00+05:30   893.00   893.65   892.70   893.50    1696.0
# ...                          ...      ...      ...      ...      ...       ...
# 370540 2021-01-01 15:25:00+05:30  2771.90  2772.95  2765.80  2769.70    5254.0
# 370541 2021-01-01 15:26:00+05:30  2768.70  2771.95  2768.65  2770.95    1889.0
# 370542 2021-01-01 15:27:00+05:30  2769.95  2770.00  2769.00  2770.00    2439.0
# 370543 2021-01-01 15:28:00+05:30  2770.00  2770.40  2769.10  2770.00    2346.0
# 370544 2021-01-01 15:29:00+05:30  2769.10  2772.00  2769.10  2770.10    2975.0
#
# [370545 rows x 6 columns]

# %%
# Identify duplicate rows
duplicates = df.duplicated()
df[duplicates]
# Out:
# Empty DataFrame
# Columns: [timestamp, open, high, low, close, volume]
# Index: []

# %%
#timewise performance 
import seaborn as sns
d=df['timestamp']
sns.relplot(data=df, x='timestamp', y='close', hue='volume', height=10, aspect=4/3)

# %%
#date wise open price performance
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
df['date'] = pd.to_datetime(df.timestamp)  # d.Date = d.Date.astype('datetime64[ns]')
ax.scatter(x=df['date'], y=df['open'])
plt.show()

# %%
#date wise high,low performance
start_date = "2019-04-30"
end_date = "2021-04-30"

mask = (df['date'] >= start_date) & (df['date'] <= end_date)
asianpaint_df1 =df.loc[mask]

plt.figure(figsize=(15,10));
plt.plot(asianpaint_df1.date, asianpaint_df1.high);
plt.plot(asianpaint_df1.date,asianpaint_df1.low);
plt.title("Trends of Asian Paint Stock 2020-2021");
plt.xlabel('2019-2021');
plt.ylabel('Price in INR');
plt.legend(['High','Low']);

# %%
#volume price 2019-2021
asianpaint_df1['volume'].plot()
plt.title("Asian Paint volume Price April-2019 - 2021")
plt.show()

# %%
#open,close,high,low performance
plt.figure(figsize=(20,7));
asianpaint_df1['open'].plot(label = 'Asian Paint Open Price')
asianpaint_df1['close'].plot(label = 'Asian Paint Close Price')
asianpaint_df1['high'].plot(label= 'Asian Paint High Price')
asianpaint_df1['low'].plot(label= 'Asian Paint Low Price')
plt.legend()
plt.title('Asian Paint Prices')
plt.ylabel("Stock Price")
plt.show()

# %%
#date wise high 
plt.figure(figsize=(15,12));
plt.bar(asianpaint_df1.date, asianpaint_df1.high);
plt.show()

# %%
plt.bar(asianpaint_df1.date,asianpaint_df1.volume,width=2.0)
plt.show()

# %%
#open price for a timeframe(2019-2021)
asianpaint_df1['open'].plot()
plt.title("Asian Paint Open Price April-2019-2021")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
asianpaint_df1.iloc[[asianpaint_df1['volume'].argmax()]]
# Out:
#                        timestamp     open     high     low    close    volume  \
# 294946 2020-03-12 12:46:00+05:30  1839.25  1839.85  1837.0  1839.55  955310.0
#
#                             date
# 294946 2020-03-12 12:46:00+05:30

# %%
AvgHigh = asianpaint_df1.describe()['high']['mean']
AvgLow = asianpaint_df1.describe()['low']['mean']
AvgVolume = asianpaint_df1.describe()['volume']['mean']

print("Average High Asian Paints Stock: ",AvgHigh,
     "\nAverage Low Asian Paints: ",AvgLow,
     "\nAverage Volume for Asian Paint: ", AvgVolume)
# Out:
# Average High Asian Paints Stock:  1771.2028480848571
# Average Low Asian Paints:  1769.2365599878676
# Average Volume for Asian Paint:  5240.577726917209

# %%
#close price performance(2019-2021)
asianpaint_df1['close'].plot()
plt.title("Asian Paint Close Price April-2019 - 2021")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#top high prices
high_10_price = asianpaint_df1.sort_values(by='high', ascending=False).head(10)
high_10_price
# Out:
#                        timestamp     open     high      low    close   volume  \
# 370455 2021-01-01 14:00:00+05:30  2788.45  2791.70  2788.45  2790.45  20657.0
# 370456 2021-01-01 14:01:00+05:30  2790.00  2791.50  2790.00  2790.95   5715.0
# 370457 2021-01-01 14:02:00+05:30  2790.95  2791.25  2790.00  2790.90   3663.0
# 370458 2021-01-01 14:03:00+05:30  2790.00  2790.35  2788.00  2789.00   8201.0
# 370486 2021-01-01 14:31:00+05:30  2787.30  2789.85  2787.30  2788.40   2540.0
# 370487 2021-01-01 14:32:00+05:30  2788.40  2789.85  2788.40  2789.15   1084.0
# 370488 2021-01-01 14:33:00+05:30  2789.05  2789.70  2788.15  2788.50   2164.0
# 370489 2021-01-01 14:34:00+05:30  2788.50  2789.50  2788.40  2788.55   1340.0
# 370490 2021-01-01 14:35:00+05:30  2788.55  2789.50  2788.50  2788.60   1276.0
# 370491 2021-01-01 14:36:00+05:30  2788.60  2789.40  2788.50  2789.40   1433.0
#
#                             date
# 370455 2021-01-01 14:00:00+05:30
# 370456 2021-01-01 14:01:00+05:30
# 370457 2021-01-01 14:02:00+05:30
# 370458 2021-01-01 14:03:00+05:30
# 370486 2021-01-01 14:31:00+05:30
# 370487 2021-01-01 14:32:00+05:30
# 370488 2021-01-01 14:33:00+05:30
# 370489 2021-01-01 14:34:00+05:30
# 370490 2021-01-01 14:35:00+05:30
# 370491 2021-01-01 14:36:00+05:30

# %%
#plotting date wise
plt.figure(figsize = (10,10));
plt.plot(high_10_price.date, high_10_price.low,'o-b');
plt.xlabel('Dates', size=10);
plt.ylabel('Price in INR', size=18);
plt.title('10 Highest price of Asian Paint Stock')
# Out:
# Text(0.5, 1.0, '10 Highest price of Asian Paint Stock')

# %%
#top low prices
Low_10_price= asianpaint_df1.sort_values(by='low', ascending=True).head(10)
Low_10_price
# Out:
#                        timestamp     open     high      low    close   volume  \
# 232509 2019-07-09 10:39:00+05:30  1293.05  1295.90  1291.25  1295.35  14774.0
# 232508 2019-07-09 10:38:00+05:30  1293.95  1293.95  1292.00  1293.00   7226.0
# 232516 2019-07-09 10:46:00+05:30  1293.75  1293.95  1292.35  1293.65   4188.0
# 232517 2019-07-09 10:47:00+05:30  1293.65  1294.90  1292.50  1294.90   3732.0
# 232510 2019-07-09 10:40:00+05:30  1295.85  1295.85  1292.85  1294.20  11884.0
# 232507 2019-07-09 10:37:00+05:30  1294.80  1294.80  1293.00  1293.15  11468.0
# 232506 2019-07-09 10:36:00+05:30  1297.35  1297.35  1293.05  1294.05  30005.0
# 232511 2019-07-09 10:41:00+05:30  1294.25  1294.60  1293.30  1294.25   2867.0
# 232518 2019-07-09 10:48:00+05:30  1295.00  1295.00  1293.45  1294.55   3886.0
# 232512 2019-07-09 10:42:00+05:30  1294.35  1294.95  1293.50  1293.60   2158.0
#
#                             date
# 232509 2019-07-09 10:39:00+05:30
# 232508 2019-07-09 10:38:00+05:30
# 232516 2019-07-09 10:46:00+05:30
# 232517 2019-07-09 10:47:00+05:30
# 232510 2019-07-09 10:40:00+05:30
# 232507 2019-07-09 10:37:00+05:30
# 232506 2019-07-09 10:36:00+05:30
# 232511 2019-07-09 10:41:00+05:30
# 232518 2019-07-09 10:48:00+05:30
# 232512 2019-07-09 10:42:00+05:30

# %%
#plotting date wise
plt.figure(figsize = (10,10));
plt.plot(Low_10_price.date, Low_10_price.low,'o-b');
plt.xlabel('Dates', size=10);
plt.ylabel('Price in INR', size=18);
plt.title('10 Highest price of Asian Paint Stock')
# Out:
# Text(0.5, 1.0, '10 Highest price of Asian Paint Stock')
